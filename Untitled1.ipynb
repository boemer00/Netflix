# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/davidguenoun/code/davidguenoun/wagon_final_project_netflix/Netflix/raw_data/full_data_merged.csv")

# %%
#Investigate Box Office
full_merged_data.BoxOffice.isnull().sum()/len(full_merged_data)*100
#Greater than 30% of values missing: Potentially drop feature or row
# Out:
# 50.16155088852988

# %%
#enlever les null values de Year_X
df[df[["Year_x"]].isnull().values]
df["Year_x"][8017] = 1974
df["Year_x"][11739] = 1994
# Out:
# <ipython-input-7-9dc11147240a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year_x"][8017] = 1974
# <ipython-input-7-9dc11147240a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year_x"][11739] = 1994

# %%
def transform_to_int(x):
    return int(x)
df["Year_x"] = df["Year_x"].apply(transform_to_int)

# %% [markdown]
# Edit Y_date

# %%
year_y = df["Year_y"].str.replace("–","")

# %%
year_front = year_y.apply(lambda x : x[:4])
year_front = year_front.apply(lambda x : int(x))

# %%
year_end = year_y.apply(lambda x : x[-4:])
year_end = year_end.apply(lambda x : int(x))

# %%
#explanation 
#when there is only one value, the value is the same for year_front and year_end ==> 
#if we take the average of two same values we get the value itself#

#when there is a range of value, the first value is in the year_front, and the second value is in the year_end value

# %%
#let's compute the mean for every value (standalone and range values)

# %%
year_y_mean = ((year_front +year_end)/2)

# %%
df["Year_y_mean"] = year_y_mean

# %%
#create a new column for the difference between year X and Year_y_mean

# %%
df["diff_X_Y_mean"] = df["Year_x"] - df["Year_y_mean"]
df["diff_X_Y_mean"] = df["diff_X_Y_mean"].apply(lambda x : abs(x))

# %%
#applying a filter

# %%
df = df.loc[df["diff_X_Y_mean"] <= 2]

# %%
df
# Out:
#        movie_id  Year_x                  Name      mean  count  \
# 0             1    2003       Dinosaur Planet  3.749543    547
# 1             3    1997             Character  3.641153   2012
# 2             6    1997                  Sick  3.084396   1019
# 3             7    1992                 8 Man  2.129032     93
# 5            12    1947  My Favorite Brunette  3.417582    546
# ...         ...     ...                   ...       ...    ...
# 12375     17763    1978             Interiors  3.411855   1957
# 12376     17764    1998   Shakespeare in Love  3.867112  64957
# 12377     17768    2000                 Epoch  2.839207   1362
# 12378     17769    2003           The Company  2.498592   6749
# 12379     17770    2003          Alien Hunter  2.816504    921
#
#                       Title Year_y      Rated     Released  Runtime  ...  \
# 0           Dinosaur Planet  2003–        NaN  14 Dec 2003   50 min  ...
# 1                 Character   1997          R  27 Mar 1998  122 min  ...
# 2                      Sick   1997  Not Rated  07 Nov 1997   90 min  ...
# 3                     8 Man   1992        NaN          NaN   83 min  ...
# 5      My Favorite Brunette   1947     Passed  04 Apr 1947   87 min  ...
# ...                     ...    ...        ...          ...      ...  ...
# 12375             Interiors   1978         PG  06 Oct 1978   92 min  ...
# 12376   Shakespeare in Love   1998          R  08 Jan 1999  123 min  ...
# 12377                 Epoch   2001      PG-13  24 Nov 2001   96 min  ...
# 12378           The Company   2003      PG-13  20 May 2004  112 min  ...
# 12379          Alien Hunter   2003          R  19 Jul 2003   92 min  ...
#
#       Error          DVD     BoxOffice  \
# 0       NaN          NaN           NaN
# 1       NaN  04 Feb 2003      $623,983
# 2       NaN  15 Feb 2017      $116,806
# 3       NaN          NaN           NaN
# 5       NaN  10 Mar 2016           NaN
# ...     ...          ...           ...
# 12375   NaN  02 Feb 2017   $10,432,366
# 12376   NaN  21 Apr 2016  $100,317,794
# 12377   NaN  25 Jan 2017           NaN
# 12378   NaN  16 Apr 2012    $2,283,914
# 12379   NaN  20 Apr 2013           NaN
#
#                                               Production Website  \
# 0                                                    NaN     NaN
# 1                                          Almerica Film     NaN
# 2      Sick-the Life and Death of Bob Flanagan-Superm...     NaN
# 3                                                    NaN     NaN
# 5                   Paramount Pictures, Hope Enterprises     NaN
# ...                                                  ...     ...
# 12375                          Rollins-Joffe Productions     NaN
# 12376  Miramax Films, Bedford Falls Productions, Univ...     NaN
# 12377                                Metro-Goldwyn-Mayer     NaN
# 12378  First Snow Production, Capitol Films, Sandcast...     NaN
# 12379                                                NaN     NaN
#
#       Rotten Tomatoes Metacritic Ratings Year_y_mean  diff_X_Y_mean
# 0                 NaN        NaN     NaN      2003.0            0.0
# 1                 92%        NaN     NaN      1997.0            0.0
# 2                 91%     82/100     NaN      1997.0            0.0
# 3                 NaN        NaN     NaN      1992.0            0.0
# 5                 75%        NaN     NaN      1947.0            0.0
# ...               ...        ...     ...         ...            ...
# 12375             79%     67/100     NaN      1978.0            0.0
# 12376             92%     87/100     NaN      1998.0            0.0
# 12377             16%        NaN     NaN      2001.0            1.0
# 12378             72%     73/100     NaN      2003.0            0.0
# 12379             16%        NaN     NaN      2003.0            0.0
#
# [9773 rows x 36 columns]
