# %%
import re
import pandas as pd

# %%
df = pd.read_csv('/Users/renatoboemer/code/boemer00/Netflix/raw_data/df_train.csv')

# %%
df.head(3)
# Out:
#    avg_review_score  n_reviews  year            title            Title  Year  \
# 0          3.749543        547  2003  Dinosaur Planet  Dinosaur Planet  2003
# 1          3.641153       2012  1997        Character        Character  1997
# 2          3.084396       1019  1997             Sick             Sick  1997
#
#        Rated   Released  Runtime                           Genre  ...  \
# 0        NaN  14-Dec-03   50 min  Documentary, Animation, Family  ...
# 1          R  27-Mar-98  122 min           Crime, Drama, Mystery  ...
# 2  Not Rated  07-Nov-97   90 min                     Documentary  ...
#
#   Response Internet Movie Database Index_match        DVD BoxOffice  \
# 0     True                  7.7/10           1        NaN       NaN
# 1     True                  7.7/10           3  04-Feb-03  $623,983
# 2     True                  7.5/10           6  15-Feb-17  $116,806
#
#                                           Production Website Rotten Tomatoes  \
# ...

# %%
class CleanReleasedEncoder(x):
            
    def transform(x, y=None):
        final =np.array([re.findall("[a-zA-Z]+",row[0])for row in x])
        return final

    def fit(x, y=None):
        return x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-35f28461fd1c> in <module>
# ----> 1 class CleanReleasedEncoder(x):
#       2
#       3     def transform(x, y=None):
#       4         final =np.array([re.findall("[a-zA-Z]+",row[0])for row in x])
#       5         return final
#
# NameError: name 'x' is not defined

# %%
def set_pipeline(self):
        pipe_language_features = Pipeline([('country', SimpleImputer(strategy='constant', fill_value="unknown")),
                                           ('language_encoder', CleanLanguageEncoder())])
