# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/davidguenoun/code/davidguenoun/wagon_final_project_netflix/Netflix/raw_data/full_data_merged.csv") 
df[["Language"]]
# Out:
#                                 Language
# 0                                English
# 1         Dutch, English, German, French
# 2                                English
# 3                               Japanese
# 4      Danish, Turkish, English, Chinese
# ...                                  ...
# 12375                            English
# 12376                            English
# 12377                            English
# 12378                            English
# 12379                   English, Russian
#
# [12380 rows x 1 columns]

# %%
df["Language"] = df[["Language"]].fillna("English")

# %%
df["Language"].isnull().sum()
# Out:
# 0

# %%
type(df["Language"][1])
# Out:
# str

# %%
def language_binary(x):
    if x.find("English") != -1:
        return "English Available"
    else:
        return "English N/A"

# %%
language_binary(df["Language"][1])
language_binary(df["Language"][3])
# Out:
# 'English N/A'

# %%
df["Language_binary"] = df["Language"].map(language_binary)

# %%
df
# Out:
#        movie_id  Year_x                 Name      mean  count  \
# 0             1  2003.0      Dinosaur Planet  3.749543    547
# 1             3  1997.0            Character  3.641153   2012
# 2             6  1997.0                 Sick  3.084396   1019
# 3             7  1992.0                8 Man  2.129032     93
# 4            10  2001.0              Fighter  3.180723    249
# ...         ...     ...                  ...       ...    ...
# 12375     17763  1978.0            Interiors  3.411855   1957
# 12376     17764  1998.0  Shakespeare in Love  3.867112  64957
# 12377     17768  2000.0                Epoch  2.839207   1362
# 12378     17769  2003.0          The Company  2.498592   6749
# 12379     17770  2003.0         Alien Hunter  2.816504    921
#
#                      Title Year_y      Rated     Released  Runtime  ...  \
# 0          Dinosaur Planet  2003–        NaN  14 Dec 2003   50 min  ...
# 1                Character   1997          R  27 Mar 1998  122 min  ...
# 2                     Sick   1997  Not Rated  07 Nov 1997   90 min  ...
# 3                    8 Man   1992        NaN          NaN   83 min  ...
# 4                  Fighter   2007        NaN  14 Dec 2007  100 min  ...
# ...                    ...    ...        ...          ...      ...  ...
# 12375            Interiors   1978         PG  06 Oct 1978   92 min  ...
# 12376  Shakespeare in Love   1998          R  08 Jan 1999  123 min  ...
# 12377                Epoch   2001      PG-13  24 Nov 2001   96 min  ...
# 12378          The Company   2003      PG-13  20 May 2004  112 min  ...
# 12379         Alien Hunter   2003          R  19 Jul 2003   92 min  ...
#
#       Response Error          DVD     BoxOffice  \
# 0         True   NaN          NaN           NaN
# 1         True   NaN  04 Feb 2003      $623,983
# 2         True   NaN  15 Feb 2017      $116,806
# 3         True   NaN          NaN           NaN
# 4         True   NaN          NaN           NaN
# ...        ...   ...          ...           ...
# 12375     True   NaN  02 Feb 2017   $10,432,366
# 12376     True   NaN  21 Apr 2016  $100,317,794
# 12377     True   NaN  25 Jan 2017           NaN
# 12378     True   NaN  16 Apr 2012    $2,283,914
# 12379     True   NaN  20 Apr 2013           NaN
#
#                                               Production Website  \
# 0                                                    NaN     NaN
# 1                                          Almerica Film     NaN
# 2      Sick-the Life and Death of Bob Flanagan-Superm...     NaN
# 3                                                    NaN     NaN
# 4                                     First Run Features     NaN
# ...                                                  ...     ...
# 12375                          Rollins-Joffe Productions     NaN
# 12376  Miramax Films, Bedford Falls Productions, Univ...     NaN
# 12377                                Metro-Goldwyn-Mayer     NaN
# 12378  First Snow Production, Capitol Films, Sandcast...     NaN
# 12379                                                NaN     NaN
#
#       Rotten Tomatoes Metacritic Ratings    Language_binary
# 0                 NaN        NaN     NaN  English Available
# 1                 92%        NaN     NaN  English Available
# 2                 91%     82/100     NaN  English Available
# 3                 NaN        NaN     NaN        English N/A
# 4                 NaN        NaN     NaN  English Available
# ...               ...        ...     ...                ...
# 12375             79%     67/100     NaN  English Available
# 12376             92%     87/100     NaN  English Available
# 12377             16%        NaN     NaN  English Available
# 12378             72%     73/100     NaN  English Available
# 12379             16%        NaN     NaN  English Available
#
# [12380 rows x 35 columns]
