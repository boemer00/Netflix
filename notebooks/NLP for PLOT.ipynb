# %%
import pandas as pd
pd.set_option('max_columns', None)
df = pd.read_csv('/Users/davidguenoun/code/davidguenoun/wagon_final_project_netflix/Netflix/raw_data/df_train.csv')
df.head()
# Out:
#    avg_review_score  n_reviews  year                 title  \
# 0          3.749543        547  2003       Dinosaur Planet
# 1          3.641153       2012  1997             Character
# 2          3.084396       1019  1997                  Sick
# 3          2.129032         93  1992                 8 Man
# 4          3.417582        546  1947  My Favorite Brunette
#
#                   Title  Year      Rated   Released  Runtime  \
# 0       Dinosaur Planet  2003        NaN  14-Dec-03   50 min
# 1             Character  1997          R  27-Mar-98  122 min
# 2                  Sick  1997  Not Rated  07-Nov-97   90 min
# 3                 8 Man  1992        NaN        NaN   83 min
# 4  My Favorite Brunette  1947     Passed  04-Apr-47   87 min
#
#                                        Genre           Director  \
# 0             Documentary, Animation, Family                NaN
# 1                      Crime, Drama, Mystery      Mike van Diem
# ...

# %%
df[["avg_review_score","Plot","Director","Writer","Actors","Genre"]]
# Out:
#       avg_review_score                                               Plot  \
# 0             3.749543  A four-episode animated series charting the ad...
# 1             3.641153  Jacob Katadreuffe lives mute with his mother, ...
# 2             3.084396  Diagnosed with cystic fibrosis from a young ag...
# 3             2.129032  After Tokyo police officer Yokoda is killed in...
# 4             3.417582  Shortly before his execution on the death row ...
# ...                ...                                                ...
# 8304          3.568646  Mourning his dead child, a haunted Vietnam War...
# 8305          2.287037  The reincarnated spirit of The Crimson Executi...
# 8306          3.792402  Operation Market Garden, September 1944: The A...
# 8307          2.918919  A poor girl is rebuked by a rich boy. She leav...
# 8308          3.199859  Mercenary James Shannon, on a reconnaissance j...
#
#                   Director                                             Writer  \
# ...

# %%
RNN NLP
distill bert ==> hugging face
trainable = false
rajouter 2-3 couches de dense layers
rajouter une prediction layers
convertir proba en polarisant/non polarisant (niveau de réaction des gens)
KNN 3 clusters : moyen, peu bcp de polarisant 
kelbow method : trouver le meilleure nombre de cluster K
